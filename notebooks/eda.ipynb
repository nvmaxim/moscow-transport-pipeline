# %%
import duckdb

con = duckdb.connect("/home/nvmaxim/Projects/moscow-transport-pipeline/data/transport.db")
con.execute("SELECT * FROM routes LIMIT 10").df()
# Out:
#       route_id agency_id route_short_name  \
# 0  100457-1229  100457-1               н4
# 1   100457-202  100457-1              279
# 2   100457-585  100457-1              149
# 3   100457-392  100457-1             1002
# 4   100457-214  100457-1              111
# 5   100457-104  100457-1              135
# 6   100457-328  100457-1              196
# 7   100457-416  100457-1               32
# 8   100457-624  100457-1               40
# 9   100457-853  100457-1               69
#
#                                      route_long_name route_desc  route_type  \
# 0                   Новокосино - Метро «Китай-город»       None           3
# 1    2-й микрорайон Жулебина - Метро «Нижегородская»       None           3
# 2                            Коровино - МЦД Дегунино       None           3
# 3                       Киевский - Метро «Саларьево»       None           3
# 4              Улица Новаторов - Метро «Октябрьская»       None           3
# ...

# %%
# Все таблицы
con.execute("SHOW TABLES").df()
# Out:
#          name
# 0      agency
# 1    calendar
# 2      routes
# 3  stop_times
# 4       stops
# 5       trips

# %%
# Структура конкретной таблицы (колонки, типы)
con.execute("DESCRIBE stops").df()
# Out:
#             column_name column_type null   key default extra
# 0               stop_id     VARCHAR  YES  None    None  None
# 1             stop_code     VARCHAR  YES  None    None  None
# 2             stop_name     VARCHAR  YES  None    None  None
# 3             stop_desc     VARCHAR  YES  None    None  None
# 4              stop_lat      DOUBLE  YES  None    None  None
# 5              stop_lon      DOUBLE  YES  None    None  None
# 6               zone_id     VARCHAR  YES  None    None  None
# 7              stop_url     VARCHAR  YES  None    None  None
# 8         location_type      BIGINT  YES  None    None  None
# 9        parent_station     VARCHAR  YES  None    None  None
# 10        stop_timezone     VARCHAR  YES  None    None  None
# 11  wheelchair_boarding      BIGINT  YES  None    None  None
# 12             level_id     VARCHAR  YES  None    None  None
# 13        platform_code     VARCHAR  YES  None    None  None

# %%
# Структура всех таблиц сразу
for table in con.execute("SHOW TABLES").fetchall():
    t = table[0]
    print(f"\n=== {t} ===")
    display(con.execute(f"DESCRIBE {t}").df())
# Out:
# === agency ===
#        column_name column_type null   key default extra
# 0        agency_id     VARCHAR  YES  None    None  None
# 1      agency_name     VARCHAR  YES  None    None  None
# 2       agency_url     VARCHAR  YES  None    None  None
# 3  agency_timezone     VARCHAR  YES  None    None  None
# 4      agency_lang     VARCHAR  YES  None    None  None
# 5     agency_phone     VARCHAR  YES  None    None  None
# 6  agency_fare_url     VARCHAR  YES  None    None  None
# 7     agency_email     VARCHAR  YES  None    None  None
# === calendar ===
#   column_name column_type null   key default extra
# 0  service_id     VARCHAR  YES  None    None  None
# 1      monday      BIGINT  YES  None    None  None
# 2     tuesday      BIGINT  YES  None    None  None
# 3   wednesday      BIGINT  YES  None    None  None
# 4    thursday      BIGINT  YES  None    None  None
# 5      friday      BIGINT  YES  None    None  None
# 6    saturday      BIGINT  YES  None    None  None
# ...
